# %% [markdown]
# # 01_EDA - Appliances Energy Prediction Dataset
#
# Exploratory Data Analysis for energy consumption prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

# Load data
df = pd.read_csv('../data/raw/energydata_complete.csv')
print(df.shape)
df.head()

# %%
# Basic info
print(df.info())
print(df.describe())
print('Missing values:\n', df.isnull().sum().sum())

# %%
# Target distribution
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.histplot(df['Appliances'], bins=50, kde=True)
plt.title('Appliances Energy (kWh) Distribution')
plt.subplot(1,2,2)
sns.boxplot(y=df['Appliances'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap (select key features)
key_features = ['Appliances', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility', 'Tdew', 'RV1', 'RV2']
corr = df[key_features].corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
# Feature correlations with target
correlations = df.corr()['Appliances'].sort_values(ascending=False)
print(correlations)
plt.figure(figsize=(10,6))
correlations.drop('Appliances').plot(kind='barh')
plt.title('Feature Correlations with Appliances')
plt.show()

# %%
# Time patterns (if date column exists, but dataset has no date; assume NSM or lights for time)
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
sns.scatterplot(x='NSM', y='Appliances', data=df)
plt.title('Appliances vs NSM')
plt.subplot(1,3,2)
sns.scatterplot(x='Week', y='Appliances', data=df)
plt.title('Appliances vs Week')
plt.subplot(1,3,3)
sns.scatterplot(x='Day_of_week', y='Appliances', data=df)
plt.title('Appliances vs Day of Week')
plt.tight_layout()
plt.show()
